# %% [markdown]
# <a href="https://colab.research.google.com/github/Kav1n-Lal/GUVI-ASSIGNMENTS/blob/main/Revised_aadhar_mongodb_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qrcode
# !pip install pillow
# !pip install fpdf2
import pymongo
client = pymongo.MongoClient("mongodb+srv://KPKAVIN:kasaan@cluster0.3bc5s5h.mongodb.net/?retryWrites=true&w=majority")
db=client.sample_aadhar

print("Enter '1' to create new aadhar \nEnter '12' to view deatails \nEnter '2' to update aadhar \nEnter '3' to request pdf download \nEnter '4' to download aadhar with qrcode")
start=input("Your option: ")

if start=='1':
    dict1={"name":'',"photo":'',"DOB":'',"Address":'',"gender":'',"EduQual":'',"email":'','Aadhar':'',
          "Aadhar created on":'',"Aadhar renewal date":'',"qrcode":''}
    def per():
      name=input("Enter your name: ")
      x=name.split()
      y=''.join(x)
      if y.isalpha()==True:
        dict1["name"]=name
      else:
        print("Enter your name as in voter id")
        per()
    per()

    def pad():
      
      from PIL import Image
      import io
      photo=input("Enter your photo Path: ") 
      im = Image.open(f'{photo}')
      
      image_bytes = io.BytesIO()
      im.save(image_bytes, format='png')
      
      ph =image_bytes.getvalue()
      dict1["photo"]=ph
    pad()

    def DOB():
      DOB_check=input("enter your DOB(dd/mm/yyyy) format: ")
      v=[]
      s=[]
      for i in DOB_check:
        s.append(i)
      # print(s)
      if s.count('/')==2:
        a=DOB_check.replace('/','')
        if len(a)>3 and len(a)<10:
          q=s.index('/')
          w=s.remove('/')
          r=s.index('/')
          date=s[:q]
          month=s[q:r]
          year=s[r+1:]
          # print(date,month,year)
          if len(year)==4:
            d1=int(''.join(date))
            m1=int(''.join(month))
            y1=int(''.join(year))
            if m1==1 or m1==3 or m1==5 or m1==7 or m1==8 or m1==10 or m1==12:
              max_days=31
            elif m1==4 or m1==6 or m1==9 or m1==11:
              max_days=30
            elif y1%4==0 and y1%100!=0 or y1%400==0:
              max_days=29
            else:
              max_days=28
            if m1>12 or m1<1:
              print("month is not in the valid range(1-12)\nCheck your month")
              DOB()
            elif d1>max_days or d1<1:
              print("date is not in the valid range(1-12)\nCheck your date")
              DOB()
            else:
              # print("ok")
              v.append('1')
          else:
            print('Please re-enter year in four digits')
            DOB()
      else:
        print("separate date,month and year using '/'(slash)")
        DOB()
      if len(v)==1:
        dict1["DOB"]=DOB_check
        # print(dict1)
    DOB()


    mug={'Door_no':'','Street_name':'','Area':'','State':'','Pincode':''}
    def dres():
      d=input("Enter Door no.: ")
      mug['Door_no']=d
      s=input("Enter street name: ")
      mug['Street_name']=s
      c=input("Enter city name: ")
      mug['Area']=c
      st=input("Enter state name: ")
      mug['State']=st
    dres()

    def pincode():
      p=input("Enter pincode: ")
      if len(p)==6 and p.isnumeric()==True:
        mug['Pincode']=p
      else:
        print("pincode must be in six digits")
        pincode()
    pincode()


    p=[]
    for k in (mug):
      p.append(mug[k])
    l=[]
    for y in p:
      if y!='':
        l.append(y)

    if len(l)==5:
      dict1["Address"]=mug
      # print(dict1)
    else:
      print("Enter missing values")
      dres()

    def pal():
      print("Type 'm' for male\nType 'f' for female\nType 't' for transgender" )
      s=input("Enter your gender(m/f/t): ")
      if s.upper()=='M':
        dict1["gender"]="Male"
      elif s.upper()=='F':
        dict1["gender"]="Female"
      elif s.upper()=='T':
        dict1["gender"]="Transgender"
      else:
        print('Type any one of the given genders')
        pal()
    pal()
    # print(dict1)

    qua={"na":'','stream':''}
    def edu():
      print("Type 'NA' if not applicable\nType '10' for sslc\nType '12' for Hsc\nType 'UG' or 'PG' or 'PHD' for degree")
      e=input("Enter Highest Educational qualification: ")
      if e.upper()=="NA":
        qua["na"]="-"
      elif e=="10":
        qua["na"]="SSLC"
      elif e=="12":
        qua["na"]="HSC"
      elif e.upper()=="UG":
        f=input("Enter Stream: ")
        qua["na"]="Bachelors"
        qua["stream"]=f
      elif e.upper()=="PG":
        f=input("Enter Stream: ")
        qua["na"]="Masters"
        qua["stream"]=f
      elif e.upper()=="PHD":
        f=input("Enter Stream: ")
        qua["na"]="Doctorate"
        qua["stream"]=f
      else:
        print('Invalid entry')
        edu()
      
      if qua["na"]==("UG" or "PG" or "PHD") and (qua["stream"].isalpha()==False):
        print("enter correct stream name")
        edu()
      else:
        dict1["EduQual"]=qua
    edu()
    t=[]
    for x in qua:
      t.append(qua.get(x))

    def reg():
      Email_ID=input('Enter EmailID: ')
      
      c=[]
      v=[]
      if Email_ID[0].isalpha()==True:
          v.append(Email_ID[0])
          c.append('3')
      elif len(v)==1:
        pass
        c.append('3')
      elif len(v)==0:
        print('''it should not start with special characters and numbers''')
        reg()
      try:
        d=Email_ID.index('@')
        e=Email_ID.index('.')
        if (e==d+1) or (d==e+1):
          print('''there should not be any "." immediate next to "@"''')
          reg()
        elif d<e:
          c.append('2')
      except ValueError:
        pass
      
      k=Email_ID.split()
      if ('@') or ('.') in k:
        pass
      else:
        print('"@" or "." missing')
        reg()
          
      
      if Email_ID.count('@') == 1 and Email_ID.count('.') == 1:
        c.append('1')
        
      elif Email_ID.count('@') > 1 or Email_ID.count('.') > 1:
        print("""'@'and '.' must not be repeated.Only once of either '.' or '@' is permissible""")
        reg()
        
      
      if len(c)==3:
        dict1["email"]=Email_ID
        print('Good EmailID\nYour Data has been uploaded')
      else:
        print(c)
        print('"@" or "." missing')
        reg()
    reg()
    def ada():
      import random
      g1=random.randint(4000,4100)
      g2=random.randint(4200,4300)
      g3=random.randint(4400,4500)
      Aa=(str(g1)+' '+str(g2)+' '+str(g3))
      dict1['Aadhar']=Aa
    ada()

    def renew():
      from datetime import date
      today = date.today()
      # dd/mm/YY
      d1 = today.strftime("%d/%m/%Y")
      dict1["Aadhar created on"]=d1
      dict1["Aadhar renewal date"]=(d1[:-4]+str(int(d1[-4:])+10))
    renew()
    # print(t)
    # print(dict1)
    dct1=[dict1["name"],dict1["photo"],dict1["DOB"],dict1["Address"],dict1["gender"],dict1["EduQual"]["na"],dict1["email"],dict1['Aadhar'],
          dict1["Aadhar created on"],dict1["Aadhar renewal date"]]


    dct2=db.aadhar_collection.insert_one(dict1)
    print(dct1)

elif start=='12':
  view=input('Enter name as given earlier: ')
  v=db.aadhar_collection.find_one({"name":f'{view}'})
  print(v)

elif start=='2':
  check=input("Enter Aadhar number: ")
  l=db.aadhar_collection.find_one({"Aadhar":f'{check}'})

  print("Enter '1' to edit address \nEnter '2' to edit Educational qualification")
  choice=input('What would you like to edit: ')
  
  if choice=='1':
    print("Enter 'a' to edit door number \nEnter 'b' to edit street name \nEnter 'c' to edit city,state,pincode")
    choice1=input("Enter option: ")
    if choice1=='a':
      check=input("Enter Aadhar number: ")
      newdoor=input("Enter new door no: ")
      db.aadhar_collection.update_one({"Aadhar":f'{check}'},{"$set":{'Address.Door_no':f'{newdoor}'}})
    elif choice1=='b':
      check=input("Enter Aadhar number: ")
      newdoor=input("Enter new street name: ")
      db.aadhar_collection.update_one({"Aadhar":f'{check}'},{"$set":{'Address.Street_name':f'{newdoor}'}})
    elif choice1=='c':
      check=input("Enter Aadhar number: ")
      newdoor=input("Enter new city name: ")
      db.aadhar_collection.update_one({"Aadhar":f'{check}'},{"$set":{'Address.Area':f'{newdoor}'}})
      newdoor=input("Enter the new state name: ")
      db.aadhar_collection.update_one({"Aadhar":f'{check}'},{"$set":{'Address.State':f'{newdoor}'}})
      def pincode():
        p=input("Enter pincode: ")
        if len(p)==6 and p.isnumeric()==True:
           db.aadhar_collection.update_one({"Aadhar":f'{check}'},{"$set":{'Address.Pincode':f'{p}'}})
        else:
          print("pincode must be in six digits")
          pincode()
      pincode()
  else:
      check=input("Enter Aadhar number: ")
      newdoor=input("Enter 10/12/UG/PG/Phd: ")
      db.aadhar_collection.update_one({"Aadhar":f'{check}'},{"$set":{'EduQual.na':f'{newdoor.upper()}'}})
      if newdoor.upper()==('UG') or ("PG") or ("PHD"):
        stre=input('Enter Stream: ')
        db.aadhar_collection.update_one({"Aadhar":f'{check}'},{"$set":{'EduQual.stream':f'{stre}'}})

elif start=='3':
  print('NOTE:Kindly Request aadhar pdf first by entering "A"!!,upload the generated aadhar.pdf file in the google drive,get the link and then request QR code by entering "Q"!! \nEnter "A" to request aadhar pdf  \nEnter "Q" to generate  qrcode ')
  rate=input()
  if rate.upper()=='A':
  # !pip install fpdf2
    gen=input('Enter Aadhar number: ')
    l=db.aadhar_collection.find_one({"Aadhar":f'{gen}'})
    
    from fpdf import FPDF
    pdf=FPDF('P','mm','A4')
    pdf.add_page()
    pdf.set_font('times','',16)
    pdf.image('/content/aadhar logo1.png',30,10,150)

    n1=l["name"]
    pdf.set_xy(20,100)
    pdf.cell(50,10,"Name:",0,align='R')
    pdf.cell(50,10,f"{n1}",0,align='L')

    from PIL import Image
    import io
    # l=aadhar_collection.find_one({"Aadhar":f'{gen}'})
    a=Image.open(io.BytesIO(l["photo"]))
    pdf.image(a,125,100,40)
    

    d1=l["DOB"]
    pdf.set_xy(20,110)
    pdf.cell(50,10,"DOB:",align='R')
    pdf.cell(50,10,f"{d1}",0,align='L')

    dn1=l["Address"]['Door_no']
    pdf.set_xy(20,120)
    pdf.cell(50,10,"Door no:",align='R')
    pdf.cell(50,10,f"{dn1}",0,align='L')

    dn2=l["Address"]['Street_name']
    pdf.set_xy(20,130)
    pdf.cell(50,10,"Street name:",0,align='R')
    pdf.cell(50,10,f"{dn2}",0,align='L')

    dn3=l["Address"]['Area']
    pdf.set_xy(20,140)
    pdf.cell(50,10,"City:",0,align='R')
    pdf.cell(50,10,f"{dn3}",0,align='L')

    dn4=l["Address"]['State']
    pdf.set_xy(20,150)
    pdf.cell(50,10,"State:",0,align='R')
    pdf.cell(50,10,f"{dn4}",0,align='L')

    dn5=l["Address"]['Pincode']
    pdf.set_xy(20,160)
    pdf.cell(50,10,"Pincode:",0,align='R')
    pdf.cell(50,10,f"{dn5}",0,align='L')

    dn6=l["gender"]
    pdf.set_xy(20,170)
    pdf.cell(50,10,"Gender:",0,align='R')
    pdf.cell(50,10,f"{dn6}",0,align='L')

    dn7=l["email"]
    pdf.set_xy(20,180)
    pdf.cell(50,10,"Email:",0,align='R')
    pdf.cell(50,10,f"{dn7}",0,align='L')


    pdf.set_font('times','BU',20)
    pdf.set_xy(60,200)
    pdf.cell(105,10,"Your Aadhar no ",0,align='C')

    pdf.set_font('times','B',22)
    dn8=l["Aadhar"]
    pdf.set_xy(60,210)
    pdf.cell(105,10,f"{dn8}",1,align='C')

    dn9=l["Aadhar created on"]
    pdf.set_font('times','',14)
    pdf.set_xy(20,240)
    pdf.cell(50,10,"Aadhar created on:",0,align='L')
    pdf.cell(50,10,f"{dn9}",0,align='L')

    dn10=l["Aadhar renewal date"]
    pdf.set_xy(20,250)
    pdf.cell(50,10,"Aadhar renewal date:",0,align='L')
    pdf.cell(50,10,f"{dn10}",0,align='L')

    aadha_r=f'{n1}'+'aadhar'+'.'+'pdf'
    pdf.output(aadha_r)
    print('Aadhar pdf created without QR code!')
  else:
    from PIL import Image
    import io
    gen=input('Enter Aadhar number: ')
    l=db.aadhar_collection.find_one({"Aadhar":f'{gen}'})
    gen1=l["name"]
    # !pip install qrcode
    import qrcode
    #upload aadhar.pdf file in google drive,copy and paste link below
    url=input("Enter Aadhar url: ")
    img=qrcode.make(f'{url}')
    #upload the below file in google drive,get link to download aadhar
    gen2=f'{gen1}'+'QR'+'.'+'png'
    img.save(gen2)
    print('QR Code has been generated!')

elif start=='4':
  print('Be ready with your QR code filepath! ')
  gen=input('Enter Aadhar number: ')
  l=db.aadhar_collection.find_one({"Aadhar":f'{gen}'})
#    # !pip install qrcode
#   import qrcode
#   #upload aadhar.pdf file in google drive,copy and paste link below
#   url=input("Enter Aadhar url: ")
#   img=qrcode.make(f'{url}')
#   img.save('qr2.png')
# #  https://drive.google.com/file/d/1N2qRlvTQDEpZ2XPaivbSelyd4RIm9bOj/view?usp=share_link   
  
  qrc=input('Enter qr code path')
  im = Image.open(qrc)
  
  image_bytes = io.BytesIO()
  im.save(image_bytes, format='png')
  
  ph =image_bytes.getvalue()
      
  db.aadhar_collection.update_one({"Aadhar":f'{gen}'},{"$set":{'qrcode':ph}})
  
  from fpdf import FPDF
  pdf=FPDF('P','mm','A4')
  pdf.add_page()
  pdf.set_font('times','',16)
  pdf.image('/content/aadhar logo1.png',30,10,150)

  n1=l["name"]
  pdf.set_xy(20,100)
  pdf.cell(50,10,"Name:",0,align='R')
  pdf.cell(50,10,f"{n1}",0,align='L')
  
  a=Image.open(io.BytesIO(l["photo"]))
  pdf.image(a,125,100,40)
  b=Image.open(io.BytesIO(l["qrcode"]))
  pdf.image(b,125,150,40)
  
  d1=l["DOB"]
  pdf.set_xy(20,110)
  pdf.cell(50,10,"DOB:",align='R')
  pdf.cell(50,10,f"{d1}",0,align='L')

  dn1=l["Address"]['Door_no']
  pdf.set_xy(20,120)
  pdf.cell(50,10,"Door no:",align='R')
  pdf.cell(50,10,f"{dn1}",0,align='L')

  dn2=l["Address"]['Street_name']
  pdf.set_xy(20,130)
  pdf.cell(50,10,"Street name:",0,align='R')
  pdf.cell(50,10,f"{dn2}",0,align='L')

  dn3=l["Address"]['Area']
  pdf.set_xy(20,140)
  pdf.cell(50,10,"City:",0,align='R')
  pdf.cell(50,10,f"{dn3}",0,align='L')

  dn4=l["Address"]['State']
  pdf.set_xy(20,150)
  pdf.cell(50,10,"State:",0,align='R')
  pdf.cell(50,10,f"{dn4}",0,align='L')

  dn5=l["Address"]['Pincode']
  pdf.set_xy(20,160)
  pdf.cell(50,10,"Pincode:",0,align='R')
  pdf.cell(50,10,f"{dn5}",0,align='L')

  dn6=l["gender"]
  pdf.set_xy(20,170)
  pdf.cell(50,10,"Gender:",0,align='R')
  pdf.cell(50,10,f"{dn6}",0,align='L')

  dn7=l["email"]
  pdf.set_xy(20,180)
  pdf.cell(50,10,"Email:",0,align='R')
  pdf.cell(50,10,f"{dn7}",0,align='L')


  pdf.set_font('times','BU',20)
  pdf.set_xy(60,200)
  pdf.cell(105,10,"Your Aadhar no ",0,align='C')

  pdf.set_font('times','B',22)
  dn8=l["Aadhar"]
  pdf.set_xy(60,210)
  pdf.cell(105,10,f"{dn8}",1,align='C')

  dn9=l["Aadhar created on"]
  pdf.set_font('times','',14)
  pdf.set_xy(20,240)
  pdf.cell(50,10,"Aadhar created on:",0,align='L')
  pdf.cell(50,10,f"{dn9}",0,align='L')

  dn10=l["Aadhar renewal date"]
  pdf.set_xy(20,250)
  pdf.cell(50,10,"Aadhar renewal date:",0,align='L')
  pdf.cell(50,10,f"{dn10}",0,align='L')

  af=f'{n1}'+'aadhar_With_QR'+'.'+'pdf'
  pdf.output(af)
  print('Aadhar with QR code created')
# Out:
# Enter '1' to create new aadhar
# Enter '12' to view deatails
# Enter '2' to update aadhar
# Enter '3' to request pdf download
# Enter '4' to download aadhar with qrcode
# Your option: 4
# Be ready with your QR code url!
# Enter Aadhar number: 4032 4271 4473
# Enter qr2 code path/content/violetQR.png
# Aadhar with QR code created

# %%
https://drive.google.com/file/d/1S3Z0bEPwx1PXAOt81c7O7eF6yPRuyFfx/view?usp=share_link
https://drive.google.com/file/d/1uzPW9vr9_c_jI9wrRBc85VveLR6GQlqt/view?usp=share_link

# %%
https://drive.google.com/file/d/1xS4HgN9kts1lfDkNjp3e6GBPufKvi4tP/view?usp=share_link
